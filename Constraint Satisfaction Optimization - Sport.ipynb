# %%
import pandas as pd
import numpy as np

import sys
import docplex.mp
import cplex

# %%
## Teams to schedule game for
teams = ['Michigan State', 'Michigan', 'Ohio State', 'Penn State', 'Rutgers',
         'Iowa', 'Minnesota', 'Nebraska', 'Purdue', 'Wisconsin']

# %%
## data frame of teams
teams_df = pd.DataFrame(teams)
teams_df.columns = ["Teams"]
teams_df
# Out:
#             Teams
# 0  Michigan State
# 1        Michigan
# 2      Ohio State
# 3      Penn State
# 4         Rutgers
# 5            Iowa
# 6       Minnesota
# 7        Nebraska
# 8          Purdue
# 9       Wisconsin

# %%
## numbers to identify the teams
team_nums = range(len(teams))
team_nums
# Out:
# range(0, 10)

# %%
from collections import namedtuple

## create a namedtuple with each team name
game = namedtuple("game",["team_1","team_2"])

## generate all unique games to play (ie each unique team combination)
unique_games_to_play = {game(t1,t2) for t1 in team_nums for t2 in team_nums if t1 < t2}
unique_games_to_play
# Out:
# {game(team_1=0, team_2=1),
#  game(team_1=0, team_2=2),
#  game(team_1=0, team_2=3),
#  game(team_1=0, team_2=4),
#  game(team_1=0, team_2=5),
#  game(team_1=0, team_2=6),
#  game(team_1=0, team_2=7),
#  game(team_1=0, team_2=8),
#  game(team_1=0, team_2=9),
#  game(team_1=1, team_2=2),
#  game(team_1=1, team_2=3),
#  game(team_1=1, team_2=4),
#  game(team_1=1, team_2=5),
#  game(team_1=1, team_2=6),
#  game(team_1=1, team_2=7),
#  game(team_1=1, team_2=8),
#  game(team_1=1, team_2=9),
#  game(team_1=2, team_2=3),
#  game(team_1=2, team_2=4),
#  game(team_1=2, team_2=5),
#  game(team_1=2, team_2=6),
#  game(team_1=2, team_2=7),
#  game(team_1=2, team_2=8),
#  game(team_1=2, team_2=9),
#  game(team_1=3, team_2=4),
#  game(team_1=3, team_2=5),
#  game(team_1=3, team_2=6),
#  game(team_1=3, team_2=7),
#  game(team_1=3, team_2=8),
#  game(team_1=3, team_2=9),
#  game(team_1=4, team_2=5),
#  game(team_1=4, team_2=6),
#  game(team_1=4, team_2=7),
#  game(team_1=4, team_2=8),
#  game(team_1=4, team_2=9),
#  game(team_1=5, team_2=6),
#  game(team_1=5, team_2=7),
#  game(team_1=5, team_2=8),
#  game(team_1=5, team_2=9),
#  game(team_1=6, team_2=7),
#  game(team_1=6, team_2=8),
#  game(team_1=6, team_2=9),
#  game(team_1=7, team_2=8),
#  game(team_1=7, team_2=9),
#  game(team_1=8, team_2=9)}

# %%
## generate all games (each team plays twice)
all_games_to_play = {game : 2 for game in unique_games_to_play}

all_games_to_play
# Out:
# {game(team_1=5, team_2=9): 2,
#  game(team_1=4, team_2=7): 2,
#  game(team_1=1, team_2=3): 2,
#  game(team_1=6, team_2=9): 2,
#  game(team_1=4, team_2=8): 2,
#  game(team_1=5, team_2=6): 2,
#  game(team_1=0, team_2=2): 2,
#  game(team_1=2, team_2=8): 2,
#  game(team_1=0, team_2=7): 2,
#  game(team_1=8, team_2=9): 2,
#  game(team_1=1, team_2=6): 2,
#  game(team_1=3, team_2=7): 2,
#  game(team_1=2, team_2=5): 2,
#  game(team_1=0, team_2=3): 2,
#  game(team_1=5, team_2=8): 2,
#  game(team_1=1, team_2=2): 2,
#  game(team_1=4, team_2=9): 2,
#  game(team_1=6, team_2=7): 2,
#  game(team_1=2, team_2=9): 2,
#  game(team_1=1, team_2=5): 2,
#  game(team_1=3, team_2=6): 2,
#  game(team_1=0, team_2=4): 2,
#  game(team_1=2, team_2=6): 2,
#  game(team_1=4, team_2=5): 2,
#  game(team_1=1, team_2=4): 2,
#  game(team_1=3, team_2=9): 2,
#  game(team_1=0, team_2=5): 2,
#  game(team_1=1, team_2=9): 2,
#  game(team_1=2, team_2=3): 2,
#  game(team_1=0, team_2=8): 2,
#  game(team_1=3, team_2=5): 2,
#  game(team_1=0, team_2=1): 2,
#  game(team_1=2, team_2=7): 2,
#  game(team_1=7, team_2=8): 2,
#  game(team_1=7, team_2=9): 2,
#  game(team_1=4, team_2=6): 2,
#  game(team_1=6, team_2=8): 2,
#  game(team_1=5, team_2=7): 2,
#  game(team_1=3, team_2=8): 2,
#  game(team_1=0, team_2=6): 2,
#  game(team_1=1, team_2=8): 2,
#  game(team_1=1, team_2=7): 2,
#  game(team_1=0, team_2=9): 2,
#  game(team_1=3, team_2=4): 2,
#  game(team_1=2, team_2=4): 2}

# %%
## create model environment
from docplex.mp.environment import Environment
env = Environment()
env.print_information()
# Out:
# * system is: Darwin 64bit
# * Python is present, version is 3.6.8
# * docplex is present, version is (2, 9, 141)
# * CPLEX wrapper is present, version is 12.8.0.0, located at: /anaconda3/lib/python3.6/site-packages

# %%
from docplex.mp.model import Model

## create sport scheduling mp model
mdl = Model("sport_scheduling")

# %%
## week numbers
weeks = range(1, 19)

# %%
## add possibility for each game to be played on any given week. This holds all possibilities
game_week_possibilities = mdl.binary_var_matrix(all_games_to_play, weeks, lambda ij: "x_%s_%d" %(str(ij[0]), ij[1]))
game_week_possibilities
# Out:
# {(game(team_1=5, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_1'),
#  (game(team_1=5, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_2'),
#  (game(team_1=5, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_3'),
#  (game(team_1=5, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_4'),
#  (game(team_1=5, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_5'),
#  (game(team_1=5, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_6'),
#  (game(team_1=5, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_7'),
#  (game(team_1=5, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_8'),
#  (game(team_1=5, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_9'),
#  (game(team_1=5, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_10'),
#  (game(team_1=5, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_11'),
#  (game(team_1=5, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_12'),
#  (game(team_1=5, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_13'),
#  (game(team_1=5, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_14'),
#  (game(team_1=5, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_15'),
#  (game(team_1=5, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_16'),
#  (game(team_1=5, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_17'),
#  (game(team_1=5, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=9)_18'),
#  (game(team_1=4, team_2=7),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_1'),
#  (game(team_1=4, team_2=7),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_2'),
#  (game(team_1=4, team_2=7),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_3'),
#  (game(team_1=4, team_2=7),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_4'),
#  (game(team_1=4, team_2=7),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_5'),
#  (game(team_1=4, team_2=7),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_6'),
#  (game(team_1=4, team_2=7),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_7'),
#  (game(team_1=4, team_2=7),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_8'),
#  (game(team_1=4, team_2=7),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_9'),
#  (game(team_1=4, team_2=7),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_10'),
#  (game(team_1=4, team_2=7),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_11'),
#  (game(team_1=4, team_2=7),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_12'),
#  (game(team_1=4, team_2=7),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_13'),
#  (game(team_1=4, team_2=7),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_14'),
#  (game(team_1=4, team_2=7),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_15'),
#  (game(team_1=4, team_2=7),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_16'),
#  (game(team_1=4, team_2=7),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_17'),
#  (game(team_1=4, team_2=7),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=7)_18'),
#  (game(team_1=1, team_2=3),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_1'),
#  (game(team_1=1, team_2=3),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_2'),
#  (game(team_1=1, team_2=3),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_3'),
#  (game(team_1=1, team_2=3),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_4'),
#  (game(team_1=1, team_2=3),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_5'),
#  (game(team_1=1, team_2=3),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_6'),
#  (game(team_1=1, team_2=3),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_7'),
#  (game(team_1=1, team_2=3),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_8'),
#  (game(team_1=1, team_2=3),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_9'),
#  (game(team_1=1, team_2=3),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_10'),
#  (game(team_1=1, team_2=3),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_11'),
#  (game(team_1=1, team_2=3),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_12'),
#  (game(team_1=1, team_2=3),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_13'),
#  (game(team_1=1, team_2=3),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_14'),
#  (game(team_1=1, team_2=3),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_15'),
#  (game(team_1=1, team_2=3),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_16'),
#  (game(team_1=1, team_2=3),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_17'),
#  (game(team_1=1, team_2=3),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=3)_18'),
#  (game(team_1=6, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_1'),
#  (game(team_1=6, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_2'),
#  (game(team_1=6, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_3'),
#  (game(team_1=6, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_4'),
#  (game(team_1=6, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_5'),
#  (game(team_1=6, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_6'),
#  (game(team_1=6, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_7'),
#  (game(team_1=6, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_8'),
#  (game(team_1=6, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_9'),
#  (game(team_1=6, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_10'),
#  (game(team_1=6, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_11'),
#  (game(team_1=6, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_12'),
#  (game(team_1=6, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_13'),
#  (game(team_1=6, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_14'),
#  (game(team_1=6, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_15'),
#  (game(team_1=6, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_16'),
#  (game(team_1=6, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_17'),
#  (game(team_1=6, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=9)_18'),
#  (game(team_1=4, team_2=8),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_1'),
#  (game(team_1=4, team_2=8),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_2'),
#  (game(team_1=4, team_2=8),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_3'),
#  (game(team_1=4, team_2=8),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_4'),
#  (game(team_1=4, team_2=8),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_5'),
#  (game(team_1=4, team_2=8),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_6'),
#  (game(team_1=4, team_2=8),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_7'),
#  (game(team_1=4, team_2=8),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_8'),
#  (game(team_1=4, team_2=8),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_9'),
#  (game(team_1=4, team_2=8),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_10'),
#  (game(team_1=4, team_2=8),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_11'),
#  (game(team_1=4, team_2=8),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_12'),
#  (game(team_1=4, team_2=8),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_13'),
#  (game(team_1=4, team_2=8),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_14'),
#  (game(team_1=4, team_2=8),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_15'),
#  (game(team_1=4, team_2=8),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_16'),
#  (game(team_1=4, team_2=8),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_17'),
#  (game(team_1=4, team_2=8),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=8)_18'),
#  (game(team_1=5, team_2=6),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_1'),
#  (game(team_1=5, team_2=6),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_2'),
#  (game(team_1=5, team_2=6),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_3'),
#  (game(team_1=5, team_2=6),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_4'),
#  (game(team_1=5, team_2=6),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_5'),
#  (game(team_1=5, team_2=6),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_6'),
#  (game(team_1=5, team_2=6),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_7'),
#  (game(team_1=5, team_2=6),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_8'),
#  (game(team_1=5, team_2=6),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_9'),
#  (game(team_1=5, team_2=6),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_10'),
#  (game(team_1=5, team_2=6),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_11'),
#  (game(team_1=5, team_2=6),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_12'),
#  (game(team_1=5, team_2=6),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_13'),
#  (game(team_1=5, team_2=6),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_14'),
#  (game(team_1=5, team_2=6),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_15'),
#  (game(team_1=5, team_2=6),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_16'),
#  (game(team_1=5, team_2=6),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_17'),
#  (game(team_1=5, team_2=6),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=6)_18'),
#  (game(team_1=0, team_2=2),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_1'),
#  (game(team_1=0, team_2=2),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_2'),
#  (game(team_1=0, team_2=2),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_3'),
#  (game(team_1=0, team_2=2),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_4'),
#  (game(team_1=0, team_2=2),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_5'),
#  (game(team_1=0, team_2=2),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_6'),
#  (game(team_1=0, team_2=2),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_7'),
#  (game(team_1=0, team_2=2),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_8'),
#  (game(team_1=0, team_2=2),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_9'),
#  (game(team_1=0, team_2=2),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_10'),
#  (game(team_1=0, team_2=2),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_11'),
#  (game(team_1=0, team_2=2),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_12'),
#  (game(team_1=0, team_2=2),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_13'),
#  (game(team_1=0, team_2=2),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_14'),
#  (game(team_1=0, team_2=2),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_15'),
#  (game(team_1=0, team_2=2),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_16'),
#  (game(team_1=0, team_2=2),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_17'),
#  (game(team_1=0, team_2=2),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=2)_18'),
#  (game(team_1=2, team_2=8),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_1'),
#  (game(team_1=2, team_2=8),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_2'),
#  (game(team_1=2, team_2=8),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_3'),
#  (game(team_1=2, team_2=8),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_4'),
#  (game(team_1=2, team_2=8),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_5'),
#  (game(team_1=2, team_2=8),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_6'),
#  (game(team_1=2, team_2=8),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_7'),
#  (game(team_1=2, team_2=8),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_8'),
#  (game(team_1=2, team_2=8),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_9'),
#  (game(team_1=2, team_2=8),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_10'),
#  (game(team_1=2, team_2=8),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_11'),
#  (game(team_1=2, team_2=8),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_12'),
#  (game(team_1=2, team_2=8),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_13'),
#  (game(team_1=2, team_2=8),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_14'),
#  (game(team_1=2, team_2=8),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_15'),
#  (game(team_1=2, team_2=8),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_16'),
#  (game(team_1=2, team_2=8),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_17'),
#  (game(team_1=2, team_2=8),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=8)_18'),
#  (game(team_1=0, team_2=7),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_1'),
#  (game(team_1=0, team_2=7),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_2'),
#  (game(team_1=0, team_2=7),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_3'),
#  (game(team_1=0, team_2=7),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_4'),
#  (game(team_1=0, team_2=7),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_5'),
#  (game(team_1=0, team_2=7),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_6'),
#  (game(team_1=0, team_2=7),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_7'),
#  (game(team_1=0, team_2=7),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_8'),
#  (game(team_1=0, team_2=7),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_9'),
#  (game(team_1=0, team_2=7),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_10'),
#  (game(team_1=0, team_2=7),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_11'),
#  (game(team_1=0, team_2=7),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_12'),
#  (game(team_1=0, team_2=7),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_13'),
#  (game(team_1=0, team_2=7),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_14'),
#  (game(team_1=0, team_2=7),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_15'),
#  (game(team_1=0, team_2=7),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_16'),
#  (game(team_1=0, team_2=7),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_17'),
#  (game(team_1=0, team_2=7),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=7)_18'),
#  (game(team_1=8, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_1'),
#  (game(team_1=8, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_2'),
#  (game(team_1=8, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_3'),
#  (game(team_1=8, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_4'),
#  (game(team_1=8, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_5'),
#  (game(team_1=8, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_6'),
#  (game(team_1=8, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_7'),
#  (game(team_1=8, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_8'),
#  (game(team_1=8, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_9'),
#  (game(team_1=8, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_10'),
#  (game(team_1=8, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_11'),
#  (game(team_1=8, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_12'),
#  (game(team_1=8, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_13'),
#  (game(team_1=8, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_14'),
#  (game(team_1=8, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_15'),
#  (game(team_1=8, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_16'),
#  (game(team_1=8, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_17'),
#  (game(team_1=8, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=8, team_2=9)_18'),
#  (game(team_1=1, team_2=6),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_1'),
#  (game(team_1=1, team_2=6),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_2'),
#  (game(team_1=1, team_2=6),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_3'),
#  (game(team_1=1, team_2=6),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_4'),
#  (game(team_1=1, team_2=6),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_5'),
#  (game(team_1=1, team_2=6),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_6'),
#  (game(team_1=1, team_2=6),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_7'),
#  (game(team_1=1, team_2=6),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_8'),
#  (game(team_1=1, team_2=6),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_9'),
#  (game(team_1=1, team_2=6),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_10'),
#  (game(team_1=1, team_2=6),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_11'),
#  (game(team_1=1, team_2=6),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_12'),
#  (game(team_1=1, team_2=6),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_13'),
#  (game(team_1=1, team_2=6),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_14'),
#  (game(team_1=1, team_2=6),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_15'),
#  (game(team_1=1, team_2=6),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_16'),
#  (game(team_1=1, team_2=6),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_17'),
#  (game(team_1=1, team_2=6),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=6)_18'),
#  (game(team_1=3, team_2=7),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_1'),
#  (game(team_1=3, team_2=7),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_2'),
#  (game(team_1=3, team_2=7),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_3'),
#  (game(team_1=3, team_2=7),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_4'),
#  (game(team_1=3, team_2=7),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_5'),
#  (game(team_1=3, team_2=7),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_6'),
#  (game(team_1=3, team_2=7),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_7'),
#  (game(team_1=3, team_2=7),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_8'),
#  (game(team_1=3, team_2=7),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_9'),
#  (game(team_1=3, team_2=7),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_10'),
#  (game(team_1=3, team_2=7),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_11'),
#  (game(team_1=3, team_2=7),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_12'),
#  (game(team_1=3, team_2=7),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_13'),
#  (game(team_1=3, team_2=7),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_14'),
#  (game(team_1=3, team_2=7),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_15'),
#  (game(team_1=3, team_2=7),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_16'),
#  (game(team_1=3, team_2=7),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_17'),
#  (game(team_1=3, team_2=7),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=7)_18'),
#  (game(team_1=2, team_2=5),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_1'),
#  (game(team_1=2, team_2=5),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_2'),
#  (game(team_1=2, team_2=5),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_3'),
#  (game(team_1=2, team_2=5),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_4'),
#  (game(team_1=2, team_2=5),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_5'),
#  (game(team_1=2, team_2=5),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_6'),
#  (game(team_1=2, team_2=5),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_7'),
#  (game(team_1=2, team_2=5),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_8'),
#  (game(team_1=2, team_2=5),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_9'),
#  (game(team_1=2, team_2=5),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_10'),
#  (game(team_1=2, team_2=5),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_11'),
#  (game(team_1=2, team_2=5),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_12'),
#  (game(team_1=2, team_2=5),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_13'),
#  (game(team_1=2, team_2=5),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_14'),
#  (game(team_1=2, team_2=5),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_15'),
#  (game(team_1=2, team_2=5),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_16'),
#  (game(team_1=2, team_2=5),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_17'),
#  (game(team_1=2, team_2=5),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=5)_18'),
#  (game(team_1=0, team_2=3),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_1'),
#  (game(team_1=0, team_2=3),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_2'),
#  (game(team_1=0, team_2=3),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_3'),
#  (game(team_1=0, team_2=3),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_4'),
#  (game(team_1=0, team_2=3),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_5'),
#  (game(team_1=0, team_2=3),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_6'),
#  (game(team_1=0, team_2=3),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_7'),
#  (game(team_1=0, team_2=3),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_8'),
#  (game(team_1=0, team_2=3),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_9'),
#  (game(team_1=0, team_2=3),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_10'),
#  (game(team_1=0, team_2=3),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_11'),
#  (game(team_1=0, team_2=3),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_12'),
#  (game(team_1=0, team_2=3),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_13'),
#  (game(team_1=0, team_2=3),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_14'),
#  (game(team_1=0, team_2=3),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_15'),
#  (game(team_1=0, team_2=3),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_16'),
#  (game(team_1=0, team_2=3),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_17'),
#  (game(team_1=0, team_2=3),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=3)_18'),
#  (game(team_1=5, team_2=8),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_1'),
#  (game(team_1=5, team_2=8),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_2'),
#  (game(team_1=5, team_2=8),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_3'),
#  (game(team_1=5, team_2=8),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_4'),
#  (game(team_1=5, team_2=8),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_5'),
#  (game(team_1=5, team_2=8),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_6'),
#  (game(team_1=5, team_2=8),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_7'),
#  (game(team_1=5, team_2=8),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_8'),
#  (game(team_1=5, team_2=8),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_9'),
#  (game(team_1=5, team_2=8),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_10'),
#  (game(team_1=5, team_2=8),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_11'),
#  (game(team_1=5, team_2=8),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_12'),
#  (game(team_1=5, team_2=8),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_13'),
#  (game(team_1=5, team_2=8),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_14'),
#  (game(team_1=5, team_2=8),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_15'),
#  (game(team_1=5, team_2=8),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_16'),
#  (game(team_1=5, team_2=8),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_17'),
#  (game(team_1=5, team_2=8),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=8)_18'),
#  (game(team_1=1, team_2=2),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_1'),
#  (game(team_1=1, team_2=2),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_2'),
#  (game(team_1=1, team_2=2),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_3'),
#  (game(team_1=1, team_2=2),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_4'),
#  (game(team_1=1, team_2=2),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_5'),
#  (game(team_1=1, team_2=2),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_6'),
#  (game(team_1=1, team_2=2),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_7'),
#  (game(team_1=1, team_2=2),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_8'),
#  (game(team_1=1, team_2=2),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_9'),
#  (game(team_1=1, team_2=2),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_10'),
#  (game(team_1=1, team_2=2),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_11'),
#  (game(team_1=1, team_2=2),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_12'),
#  (game(team_1=1, team_2=2),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_13'),
#  (game(team_1=1, team_2=2),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_14'),
#  (game(team_1=1, team_2=2),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_15'),
#  (game(team_1=1, team_2=2),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_16'),
#  (game(team_1=1, team_2=2),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_17'),
#  (game(team_1=1, team_2=2),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=2)_18'),
#  (game(team_1=4, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_1'),
#  (game(team_1=4, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_2'),
#  (game(team_1=4, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_3'),
#  (game(team_1=4, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_4'),
#  (game(team_1=4, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_5'),
#  (game(team_1=4, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_6'),
#  (game(team_1=4, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_7'),
#  (game(team_1=4, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_8'),
#  (game(team_1=4, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_9'),
#  (game(team_1=4, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_10'),
#  (game(team_1=4, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_11'),
#  (game(team_1=4, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_12'),
#  (game(team_1=4, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_13'),
#  (game(team_1=4, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_14'),
#  (game(team_1=4, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_15'),
#  (game(team_1=4, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_16'),
#  (game(team_1=4, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_17'),
#  (game(team_1=4, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=9)_18'),
#  (game(team_1=6, team_2=7),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_1'),
#  (game(team_1=6, team_2=7),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_2'),
#  (game(team_1=6, team_2=7),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_3'),
#  (game(team_1=6, team_2=7),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_4'),
#  (game(team_1=6, team_2=7),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_5'),
#  (game(team_1=6, team_2=7),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_6'),
#  (game(team_1=6, team_2=7),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_7'),
#  (game(team_1=6, team_2=7),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_8'),
#  (game(team_1=6, team_2=7),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_9'),
#  (game(team_1=6, team_2=7),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_10'),
#  (game(team_1=6, team_2=7),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_11'),
#  (game(team_1=6, team_2=7),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_12'),
#  (game(team_1=6, team_2=7),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_13'),
#  (game(team_1=6, team_2=7),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_14'),
#  (game(team_1=6, team_2=7),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_15'),
#  (game(team_1=6, team_2=7),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_16'),
#  (game(team_1=6, team_2=7),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_17'),
#  (game(team_1=6, team_2=7),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=7)_18'),
#  (game(team_1=2, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_1'),
#  (game(team_1=2, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_2'),
#  (game(team_1=2, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_3'),
#  (game(team_1=2, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_4'),
#  (game(team_1=2, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_5'),
#  (game(team_1=2, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_6'),
#  (game(team_1=2, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_7'),
#  (game(team_1=2, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_8'),
#  (game(team_1=2, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_9'),
#  (game(team_1=2, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_10'),
#  (game(team_1=2, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_11'),
#  (game(team_1=2, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_12'),
#  (game(team_1=2, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_13'),
#  (game(team_1=2, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_14'),
#  (game(team_1=2, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_15'),
#  (game(team_1=2, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_16'),
#  (game(team_1=2, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_17'),
#  (game(team_1=2, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=9)_18'),
#  (game(team_1=1, team_2=5),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_1'),
#  (game(team_1=1, team_2=5),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_2'),
#  (game(team_1=1, team_2=5),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_3'),
#  (game(team_1=1, team_2=5),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_4'),
#  (game(team_1=1, team_2=5),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_5'),
#  (game(team_1=1, team_2=5),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_6'),
#  (game(team_1=1, team_2=5),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_7'),
#  (game(team_1=1, team_2=5),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_8'),
#  (game(team_1=1, team_2=5),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_9'),
#  (game(team_1=1, team_2=5),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_10'),
#  (game(team_1=1, team_2=5),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_11'),
#  (game(team_1=1, team_2=5),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_12'),
#  (game(team_1=1, team_2=5),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_13'),
#  (game(team_1=1, team_2=5),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_14'),
#  (game(team_1=1, team_2=5),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_15'),
#  (game(team_1=1, team_2=5),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_16'),
#  (game(team_1=1, team_2=5),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_17'),
#  (game(team_1=1, team_2=5),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=5)_18'),
#  (game(team_1=3, team_2=6),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_1'),
#  (game(team_1=3, team_2=6),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_2'),
#  (game(team_1=3, team_2=6),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_3'),
#  (game(team_1=3, team_2=6),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_4'),
#  (game(team_1=3, team_2=6),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_5'),
#  (game(team_1=3, team_2=6),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_6'),
#  (game(team_1=3, team_2=6),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_7'),
#  (game(team_1=3, team_2=6),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_8'),
#  (game(team_1=3, team_2=6),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_9'),
#  (game(team_1=3, team_2=6),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_10'),
#  (game(team_1=3, team_2=6),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_11'),
#  (game(team_1=3, team_2=6),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_12'),
#  (game(team_1=3, team_2=6),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_13'),
#  (game(team_1=3, team_2=6),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_14'),
#  (game(team_1=3, team_2=6),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_15'),
#  (game(team_1=3, team_2=6),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_16'),
#  (game(team_1=3, team_2=6),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_17'),
#  (game(team_1=3, team_2=6),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=6)_18'),
#  (game(team_1=0, team_2=4),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_1'),
#  (game(team_1=0, team_2=4),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_2'),
#  (game(team_1=0, team_2=4),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_3'),
#  (game(team_1=0, team_2=4),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_4'),
#  (game(team_1=0, team_2=4),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_5'),
#  (game(team_1=0, team_2=4),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_6'),
#  (game(team_1=0, team_2=4),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_7'),
#  (game(team_1=0, team_2=4),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_8'),
#  (game(team_1=0, team_2=4),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_9'),
#  (game(team_1=0, team_2=4),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_10'),
#  (game(team_1=0, team_2=4),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_11'),
#  (game(team_1=0, team_2=4),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_12'),
#  (game(team_1=0, team_2=4),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_13'),
#  (game(team_1=0, team_2=4),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_14'),
#  (game(team_1=0, team_2=4),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_15'),
#  (game(team_1=0, team_2=4),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_16'),
#  (game(team_1=0, team_2=4),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_17'),
#  (game(team_1=0, team_2=4),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=4)_18'),
#  (game(team_1=2, team_2=6),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_1'),
#  (game(team_1=2, team_2=6),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_2'),
#  (game(team_1=2, team_2=6),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_3'),
#  (game(team_1=2, team_2=6),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_4'),
#  (game(team_1=2, team_2=6),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_5'),
#  (game(team_1=2, team_2=6),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_6'),
#  (game(team_1=2, team_2=6),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_7'),
#  (game(team_1=2, team_2=6),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_8'),
#  (game(team_1=2, team_2=6),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_9'),
#  (game(team_1=2, team_2=6),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_10'),
#  (game(team_1=2, team_2=6),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_11'),
#  (game(team_1=2, team_2=6),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_12'),
#  (game(team_1=2, team_2=6),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_13'),
#  (game(team_1=2, team_2=6),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_14'),
#  (game(team_1=2, team_2=6),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_15'),
#  (game(team_1=2, team_2=6),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_16'),
#  (game(team_1=2, team_2=6),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_17'),
#  (game(team_1=2, team_2=6),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=6)_18'),
#  (game(team_1=4, team_2=5),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_1'),
#  (game(team_1=4, team_2=5),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_2'),
#  (game(team_1=4, team_2=5),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_3'),
#  (game(team_1=4, team_2=5),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_4'),
#  (game(team_1=4, team_2=5),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_5'),
#  (game(team_1=4, team_2=5),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_6'),
#  (game(team_1=4, team_2=5),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_7'),
#  (game(team_1=4, team_2=5),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_8'),
#  (game(team_1=4, team_2=5),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_9'),
#  (game(team_1=4, team_2=5),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_10'),
#  (game(team_1=4, team_2=5),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_11'),
#  (game(team_1=4, team_2=5),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_12'),
#  (game(team_1=4, team_2=5),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_13'),
#  (game(team_1=4, team_2=5),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_14'),
#  (game(team_1=4, team_2=5),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_15'),
#  (game(team_1=4, team_2=5),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_16'),
#  (game(team_1=4, team_2=5),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_17'),
#  (game(team_1=4, team_2=5),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=5)_18'),
#  (game(team_1=1, team_2=4),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_1'),
#  (game(team_1=1, team_2=4),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_2'),
#  (game(team_1=1, team_2=4),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_3'),
#  (game(team_1=1, team_2=4),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_4'),
#  (game(team_1=1, team_2=4),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_5'),
#  (game(team_1=1, team_2=4),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_6'),
#  (game(team_1=1, team_2=4),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_7'),
#  (game(team_1=1, team_2=4),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_8'),
#  (game(team_1=1, team_2=4),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_9'),
#  (game(team_1=1, team_2=4),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_10'),
#  (game(team_1=1, team_2=4),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_11'),
#  (game(team_1=1, team_2=4),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_12'),
#  (game(team_1=1, team_2=4),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_13'),
#  (game(team_1=1, team_2=4),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_14'),
#  (game(team_1=1, team_2=4),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_15'),
#  (game(team_1=1, team_2=4),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_16'),
#  (game(team_1=1, team_2=4),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_17'),
#  (game(team_1=1, team_2=4),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=4)_18'),
#  (game(team_1=3, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_1'),
#  (game(team_1=3, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_2'),
#  (game(team_1=3, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_3'),
#  (game(team_1=3, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_4'),
#  (game(team_1=3, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_5'),
#  (game(team_1=3, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_6'),
#  (game(team_1=3, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_7'),
#  (game(team_1=3, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_8'),
#  (game(team_1=3, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_9'),
#  (game(team_1=3, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_10'),
#  (game(team_1=3, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_11'),
#  (game(team_1=3, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_12'),
#  (game(team_1=3, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_13'),
#  (game(team_1=3, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_14'),
#  (game(team_1=3, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_15'),
#  (game(team_1=3, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_16'),
#  (game(team_1=3, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_17'),
#  (game(team_1=3, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=9)_18'),
#  (game(team_1=0, team_2=5),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_1'),
#  (game(team_1=0, team_2=5),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_2'),
#  (game(team_1=0, team_2=5),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_3'),
#  (game(team_1=0, team_2=5),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_4'),
#  (game(team_1=0, team_2=5),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_5'),
#  (game(team_1=0, team_2=5),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_6'),
#  (game(team_1=0, team_2=5),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_7'),
#  (game(team_1=0, team_2=5),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_8'),
#  (game(team_1=0, team_2=5),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_9'),
#  (game(team_1=0, team_2=5),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_10'),
#  (game(team_1=0, team_2=5),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_11'),
#  (game(team_1=0, team_2=5),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_12'),
#  (game(team_1=0, team_2=5),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_13'),
#  (game(team_1=0, team_2=5),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_14'),
#  (game(team_1=0, team_2=5),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_15'),
#  (game(team_1=0, team_2=5),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_16'),
#  (game(team_1=0, team_2=5),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_17'),
#  (game(team_1=0, team_2=5),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=5)_18'),
#  (game(team_1=1, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_1'),
#  (game(team_1=1, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_2'),
#  (game(team_1=1, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_3'),
#  (game(team_1=1, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_4'),
#  (game(team_1=1, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_5'),
#  (game(team_1=1, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_6'),
#  (game(team_1=1, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_7'),
#  (game(team_1=1, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_8'),
#  (game(team_1=1, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_9'),
#  (game(team_1=1, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_10'),
#  (game(team_1=1, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_11'),
#  (game(team_1=1, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_12'),
#  (game(team_1=1, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_13'),
#  (game(team_1=1, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_14'),
#  (game(team_1=1, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_15'),
#  (game(team_1=1, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_16'),
#  (game(team_1=1, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_17'),
#  (game(team_1=1, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=9)_18'),
#  (game(team_1=2, team_2=3),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=3)_1'),
# ...
#  (game(team_1=4, team_2=6),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=6)_13'),
#  (game(team_1=4, team_2=6),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=6)_14'),
#  (game(team_1=4, team_2=6),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=6)_15'),
#  (game(team_1=4, team_2=6),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=6)_16'),
#  (game(team_1=4, team_2=6),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=6)_17'),
#  (game(team_1=4, team_2=6),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=4, team_2=6)_18'),
#  (game(team_1=6, team_2=8),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_1'),
#  (game(team_1=6, team_2=8),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_2'),
#  (game(team_1=6, team_2=8),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_3'),
#  (game(team_1=6, team_2=8),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_4'),
#  (game(team_1=6, team_2=8),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_5'),
#  (game(team_1=6, team_2=8),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_6'),
#  (game(team_1=6, team_2=8),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_7'),
#  (game(team_1=6, team_2=8),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_8'),
#  (game(team_1=6, team_2=8),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_9'),
#  (game(team_1=6, team_2=8),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_10'),
#  (game(team_1=6, team_2=8),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_11'),
#  (game(team_1=6, team_2=8),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_12'),
#  (game(team_1=6, team_2=8),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_13'),
#  (game(team_1=6, team_2=8),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_14'),
#  (game(team_1=6, team_2=8),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_15'),
#  (game(team_1=6, team_2=8),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_16'),
#  (game(team_1=6, team_2=8),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_17'),
#  (game(team_1=6, team_2=8),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=6, team_2=8)_18'),
#  (game(team_1=5, team_2=7),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_1'),
#  (game(team_1=5, team_2=7),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_2'),
#  (game(team_1=5, team_2=7),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_3'),
#  (game(team_1=5, team_2=7),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_4'),
#  (game(team_1=5, team_2=7),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_5'),
#  (game(team_1=5, team_2=7),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_6'),
#  (game(team_1=5, team_2=7),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_7'),
#  (game(team_1=5, team_2=7),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_8'),
#  (game(team_1=5, team_2=7),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_9'),
#  (game(team_1=5, team_2=7),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_10'),
#  (game(team_1=5, team_2=7),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_11'),
#  (game(team_1=5, team_2=7),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_12'),
#  (game(team_1=5, team_2=7),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_13'),
#  (game(team_1=5, team_2=7),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_14'),
#  (game(team_1=5, team_2=7),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_15'),
#  (game(team_1=5, team_2=7),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_16'),
#  (game(team_1=5, team_2=7),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_17'),
#  (game(team_1=5, team_2=7),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=5, team_2=7)_18'),
#  (game(team_1=3, team_2=8),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_1'),
#  (game(team_1=3, team_2=8),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_2'),
#  (game(team_1=3, team_2=8),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_3'),
#  (game(team_1=3, team_2=8),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_4'),
#  (game(team_1=3, team_2=8),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_5'),
#  (game(team_1=3, team_2=8),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_6'),
#  (game(team_1=3, team_2=8),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_7'),
#  (game(team_1=3, team_2=8),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_8'),
#  (game(team_1=3, team_2=8),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_9'),
#  (game(team_1=3, team_2=8),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_10'),
#  (game(team_1=3, team_2=8),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_11'),
#  (game(team_1=3, team_2=8),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_12'),
#  (game(team_1=3, team_2=8),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_13'),
#  (game(team_1=3, team_2=8),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_14'),
#  (game(team_1=3, team_2=8),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_15'),
#  (game(team_1=3, team_2=8),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_16'),
#  (game(team_1=3, team_2=8),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_17'),
#  (game(team_1=3, team_2=8),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=8)_18'),
#  (game(team_1=0, team_2=6),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_1'),
#  (game(team_1=0, team_2=6),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_2'),
#  (game(team_1=0, team_2=6),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_3'),
#  (game(team_1=0, team_2=6),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_4'),
#  (game(team_1=0, team_2=6),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_5'),
#  (game(team_1=0, team_2=6),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_6'),
#  (game(team_1=0, team_2=6),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_7'),
#  (game(team_1=0, team_2=6),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_8'),
#  (game(team_1=0, team_2=6),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_9'),
#  (game(team_1=0, team_2=6),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_10'),
#  (game(team_1=0, team_2=6),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_11'),
#  (game(team_1=0, team_2=6),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_12'),
#  (game(team_1=0, team_2=6),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_13'),
#  (game(team_1=0, team_2=6),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_14'),
#  (game(team_1=0, team_2=6),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_15'),
#  (game(team_1=0, team_2=6),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_16'),
#  (game(team_1=0, team_2=6),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_17'),
#  (game(team_1=0, team_2=6),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=6)_18'),
#  (game(team_1=1, team_2=8),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_1'),
#  (game(team_1=1, team_2=8),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_2'),
#  (game(team_1=1, team_2=8),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_3'),
#  (game(team_1=1, team_2=8),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_4'),
#  (game(team_1=1, team_2=8),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_5'),
#  (game(team_1=1, team_2=8),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_6'),
#  (game(team_1=1, team_2=8),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_7'),
#  (game(team_1=1, team_2=8),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_8'),
#  (game(team_1=1, team_2=8),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_9'),
#  (game(team_1=1, team_2=8),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_10'),
#  (game(team_1=1, team_2=8),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_11'),
#  (game(team_1=1, team_2=8),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_12'),
#  (game(team_1=1, team_2=8),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_13'),
#  (game(team_1=1, team_2=8),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_14'),
#  (game(team_1=1, team_2=8),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_15'),
#  (game(team_1=1, team_2=8),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_16'),
#  (game(team_1=1, team_2=8),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_17'),
#  (game(team_1=1, team_2=8),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=8)_18'),
#  (game(team_1=1, team_2=7),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_1'),
#  (game(team_1=1, team_2=7),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_2'),
#  (game(team_1=1, team_2=7),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_3'),
#  (game(team_1=1, team_2=7),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_4'),
#  (game(team_1=1, team_2=7),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_5'),
#  (game(team_1=1, team_2=7),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_6'),
#  (game(team_1=1, team_2=7),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_7'),
#  (game(team_1=1, team_2=7),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_8'),
#  (game(team_1=1, team_2=7),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_9'),
#  (game(team_1=1, team_2=7),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_10'),
#  (game(team_1=1, team_2=7),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_11'),
#  (game(team_1=1, team_2=7),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_12'),
#  (game(team_1=1, team_2=7),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_13'),
#  (game(team_1=1, team_2=7),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_14'),
#  (game(team_1=1, team_2=7),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_15'),
#  (game(team_1=1, team_2=7),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_16'),
#  (game(team_1=1, team_2=7),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_17'),
#  (game(team_1=1, team_2=7),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=1, team_2=7)_18'),
#  (game(team_1=0, team_2=9),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_1'),
#  (game(team_1=0, team_2=9),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_2'),
#  (game(team_1=0, team_2=9),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_3'),
#  (game(team_1=0, team_2=9),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_4'),
#  (game(team_1=0, team_2=9),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_5'),
#  (game(team_1=0, team_2=9),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_6'),
#  (game(team_1=0, team_2=9),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_7'),
#  (game(team_1=0, team_2=9),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_8'),
#  (game(team_1=0, team_2=9),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_9'),
#  (game(team_1=0, team_2=9),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_10'),
#  (game(team_1=0, team_2=9),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_11'),
#  (game(team_1=0, team_2=9),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_12'),
#  (game(team_1=0, team_2=9),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_13'),
#  (game(team_1=0, team_2=9),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_14'),
#  (game(team_1=0, team_2=9),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_15'),
#  (game(team_1=0, team_2=9),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_16'),
#  (game(team_1=0, team_2=9),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_17'),
#  (game(team_1=0, team_2=9),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=0, team_2=9)_18'),
#  (game(team_1=3, team_2=4),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_1'),
#  (game(team_1=3, team_2=4),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_2'),
#  (game(team_1=3, team_2=4),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_3'),
#  (game(team_1=3, team_2=4),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_4'),
#  (game(team_1=3, team_2=4),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_5'),
#  (game(team_1=3, team_2=4),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_6'),
#  (game(team_1=3, team_2=4),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_7'),
#  (game(team_1=3, team_2=4),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_8'),
#  (game(team_1=3, team_2=4),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_9'),
#  (game(team_1=3, team_2=4),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_10'),
#  (game(team_1=3, team_2=4),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_11'),
#  (game(team_1=3, team_2=4),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_12'),
#  (game(team_1=3, team_2=4),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_13'),
#  (game(team_1=3, team_2=4),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_14'),
#  (game(team_1=3, team_2=4),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_15'),
#  (game(team_1=3, team_2=4),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_16'),
#  (game(team_1=3, team_2=4),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_17'),
#  (game(team_1=3, team_2=4),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=3, team_2=4)_18'),
#  (game(team_1=2, team_2=4),
#   1): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_1'),
#  (game(team_1=2, team_2=4),
#   2): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_2'),
#  (game(team_1=2, team_2=4),
#   3): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_3'),
#  (game(team_1=2, team_2=4),
#   4): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_4'),
#  (game(team_1=2, team_2=4),
#   5): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_5'),
#  (game(team_1=2, team_2=4),
#   6): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_6'),
#  (game(team_1=2, team_2=4),
#   7): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_7'),
#  (game(team_1=2, team_2=4),
#   8): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_8'),
#  (game(team_1=2, team_2=4),
#   9): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_9'),
#  (game(team_1=2, team_2=4),
#   10): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_10'),
#  (game(team_1=2, team_2=4),
#   11): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_11'),
#  (game(team_1=2, team_2=4),
#   12): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_12'),
#  (game(team_1=2, team_2=4),
#   13): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_13'),
#  (game(team_1=2, team_2=4),
#   14): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_14'),
#  (game(team_1=2, team_2=4),
#   15): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_15'),
#  (game(team_1=2, team_2=4),
#   16): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_16'),
#  (game(team_1=2, team_2=4),
#   17): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_17'),
#  (game(team_1=2, team_2=4),
#   18): docplex.mp.Var(type=B,name='x_game(team_1=2, team_2=4)_18')}

# %%
## add constraint that every game must be played
mdl.add_constraints(mdl.sum(game_week_possibilities[game, week]  for week in weeks) == all_games_to_play[game]
                   for game in unique_games_to_play)
mdl.print_information()
# Out:
# Model: sport_scheduling
#  - number of variables: 810
#    - binary=810, integer=0, continuous=0
#  - number of constraints: 45
#    - linear=45
#  - parameters: defaults

# %%
## add constraint that every team must play exactly once a week
mdl.add_constraints(mdl.sum(game_week_possibilities[game, week] 
                            for game in unique_games_to_play 
                            if (game.team_1 == team_num or game.team_2 == team_num)) == 1
                    for week in weeks for team_num in team_nums)
mdl.print_information()
# Out:
# Model: sport_scheduling
#  - number of variables: 810
#    - binary=810, integer=0, continuous=0
#  - number of constraints: 225
#    - linear=225
#  - parameters: defaults

# %%
mdl.print_information()

## solve the model
assert mdl.solve(), "!!! Solve of the model fails"
mdl.report()
# Out:
# Model: sport_scheduling
#  - number of variables: 810
#    - binary=810, integer=0, continuous=0
#  - number of constraints: 225
#    - linear=225
#  - parameters: defaults
# * model sport_scheduling solved with objective = 0

# %%
## dictionary for linking team number and team name
team_league = dict(list({t : teams[t] for t in range(10) }.items()))
team_league
# Out:
# {0: 'Michigan State',
#  1: 'Michigan',
#  2: 'Ohio State',
#  3: 'Penn State',
#  4: 'Rutgers',
#  5: 'Iowa',
#  6: 'Minnesota',
#  7: 'Nebraska',
#  8: 'Purdue',
#  9: 'Wisconsin'}

# %%
## solution named tuple
schedule = namedtuple("schedule",["week", "team_1", "team_2"])

game_schedule = [schedule(week, team_league[game.team_1], team_league[game.team_2]) 
                 for game in unique_games_to_play 
                 for week in weeks 
                 if game_week_possibilities[game, week].solution_value == 1]
game_schedule
# Out:
# [schedule(week=3, team_1='Iowa', team_2='Wisconsin'),
#  schedule(week=8, team_1='Iowa', team_2='Wisconsin'),
#  schedule(week=1, team_1='Rutgers', team_2='Nebraska'),
#  schedule(week=7, team_1='Rutgers', team_2='Nebraska'),
#  schedule(week=4, team_1='Michigan', team_2='Penn State'),
#  schedule(week=10, team_1='Michigan', team_2='Penn State'),
#  schedule(week=10, team_1='Minnesota', team_2='Wisconsin'),
#  schedule(week=14, team_1='Minnesota', team_2='Wisconsin'),
#  schedule(week=3, team_1='Rutgers', team_2='Purdue'),
#  schedule(week=13, team_1='Rutgers', team_2='Purdue'),
#  schedule(week=16, team_1='Iowa', team_2='Minnesota'),
#  schedule(week=18, team_1='Iowa', team_2='Minnesota'),
#  schedule(week=11, team_1='Michigan State', team_2='Ohio State'),
#  schedule(week=16, team_1='Michigan State', team_2='Ohio State'),
#  schedule(week=2, team_1='Ohio State', team_2='Purdue'),
#  schedule(week=17, team_1='Ohio State', team_2='Purdue'),
#  schedule(week=3, team_1='Michigan State', team_2='Nebraska'),
#  schedule(week=17, team_1='Michigan State', team_2='Nebraska'),
#  schedule(week=11, team_1='Purdue', team_2='Wisconsin'),
#  schedule(week=12, team_1='Purdue', team_2='Wisconsin'),
#  schedule(week=5, team_1='Michigan', team_2='Minnesota'),
#  schedule(week=7, team_1='Michigan', team_2='Minnesota'),
#  schedule(week=15, team_1='Penn State', team_2='Nebraska'),
#  schedule(week=16, team_1='Penn State', team_2='Nebraska'),
#  schedule(week=6, team_1='Ohio State', team_2='Iowa'),
#  schedule(week=10, team_1='Ohio State', team_2='Iowa'),
#  schedule(week=7, team_1='Michigan State', team_2='Penn State'),
#  schedule(week=9, team_1='Michigan State', team_2='Penn State'),
#  schedule(week=4, team_1='Iowa', team_2='Purdue'),
#  schedule(week=7, team_1='Iowa', team_2='Purdue'),
#  schedule(week=3, team_1='Michigan', team_2='Ohio State'),
#  schedule(week=18, team_1='Michigan', team_2='Ohio State'),
#  schedule(week=5, team_1='Rutgers', team_2='Wisconsin'),
#  schedule(week=16, team_1='Rutgers', team_2='Wisconsin'),
#  schedule(week=4, team_1='Minnesota', team_2='Nebraska'),
#  schedule(week=11, team_1='Minnesota', team_2='Nebraska'),
#  schedule(week=7, team_1='Ohio State', team_2='Wisconsin'),
#  schedule(week=15, team_1='Ohio State', team_2='Wisconsin'),
#  schedule(week=1, team_1='Michigan', team_2='Iowa'),
#  schedule(week=17, team_1='Michigan', team_2='Iowa'),
#  schedule(week=3, team_1='Penn State', team_2='Minnesota'),
#  schedule(week=6, team_1='Penn State', team_2='Minnesota'),
#  schedule(week=6, team_1='Michigan State', team_2='Rutgers'),
#  schedule(week=10, team_1='Michigan State', team_2='Rutgers'),
#  schedule(week=1, team_1='Ohio State', team_2='Minnesota'),
#  schedule(week=13, team_1='Ohio State', team_2='Minnesota'),
#  schedule(week=12, team_1='Rutgers', team_2='Iowa'),
#  schedule(week=15, team_1='Rutgers', team_2='Iowa'),
#  schedule(week=11, team_1='Michigan', team_2='Rutgers'),
#  schedule(week=14, team_1='Michigan', team_2='Rutgers'),
#  schedule(week=13, team_1='Penn State', team_2='Wisconsin'),
#  schedule(week=17, team_1='Penn State', team_2='Wisconsin'),
#  schedule(week=13, team_1='Michigan State', team_2='Iowa'),
#  schedule(week=14, team_1='Michigan State', team_2='Iowa'),
#  schedule(week=2, team_1='Michigan', team_2='Wisconsin'),
#  schedule(week=9, team_1='Michigan', team_2='Wisconsin'),
#  schedule(week=8, team_1='Ohio State', team_2='Penn State'),
#  schedule(week=12, team_1='Ohio State', team_2='Penn State'),
#  schedule(week=5, team_1='Michigan State', team_2='Purdue'),
#  schedule(week=18, team_1='Michigan State', team_2='Purdue'),
#  schedule(week=5, team_1='Penn State', team_2='Iowa'),
#  schedule(week=11, team_1='Penn State', team_2='Iowa'),
#  schedule(week=8, team_1='Michigan State', team_2='Michigan'),
#  schedule(week=15, team_1='Michigan State', team_2='Michigan'),
#  schedule(week=5, team_1='Ohio State', team_2='Nebraska'),
#  schedule(week=14, team_1='Ohio State', team_2='Nebraska'),
#  schedule(week=8, team_1='Nebraska', team_2='Purdue'),
#  schedule(week=10, team_1='Nebraska', team_2='Purdue'),
#  schedule(week=6, team_1='Nebraska', team_2='Wisconsin'),
#  schedule(week=18, team_1='Nebraska', team_2='Wisconsin'),
#  schedule(week=8, team_1='Rutgers', team_2='Minnesota'),
#  schedule(week=17, team_1='Rutgers', team_2='Minnesota'),
#  schedule(week=9, team_1='Minnesota', team_2='Purdue'),
#  schedule(week=15, team_1='Minnesota', team_2='Purdue'),
#  schedule(week=2, team_1='Iowa', team_2='Nebraska'),
#  schedule(week=9, team_1='Iowa', team_2='Nebraska'),
#  schedule(week=1, team_1='Penn State', team_2='Purdue'),
#  schedule(week=14, team_1='Penn State', team_2='Purdue'),
#  schedule(week=2, team_1='Michigan State', team_2='Minnesota'),
#  schedule(week=12, team_1='Michigan State', team_2='Minnesota'),
#  schedule(week=6, team_1='Michigan', team_2='Purdue'),
#  schedule(week=16, team_1='Michigan', team_2='Purdue'),
#  schedule(week=12, team_1='Michigan', team_2='Nebraska'),
#  schedule(week=13, team_1='Michigan', team_2='Nebraska'),
#  schedule(week=1, team_1='Michigan State', team_2='Wisconsin'),
#  schedule(week=4, team_1='Michigan State', team_2='Wisconsin'),
#  schedule(week=2, team_1='Penn State', team_2='Rutgers'),
#  schedule(week=18, team_1='Penn State', team_2='Rutgers'),
#  schedule(week=4, team_1='Ohio State', team_2='Rutgers'),
#  schedule(week=9, team_1='Ohio State', team_2='Rutgers')]
